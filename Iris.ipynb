# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-a79c6c5d-d887-4541-8939-d01df63b19ad" name="files[]" multiple disabled />
#      <output id="result-a79c6c5d-d887-4541-8939-d01df63b19ad">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Iris.csv to Iris.csv
# User uploaded file "Iris.csv" with length 5107 bytes

# %%
import pandas as pd

# %%
df = pd.read_csv('Iris.csv', sep = ',')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']].cov()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       0.685694     -0.039268       1.273682      0.516904
# SepalWidthCm       -0.039268      0.188004      -0.321713     -0.117981
# PetalLengthCm       1.273682     -0.321713       3.113179      1.296387
# PetalWidthCm        0.516904     -0.117981       1.296387      0.582414

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df['SepalLengthCm'].hist()

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['SepalLengthCm'], bins = 10, density=True)
plt.show()

# %%
df.groupby('Species')['Species'].value_counts()
# Out:
# Species          Species
# Iris-setosa      Iris-setosa        50
# Iris-versicolor  Iris-versicolor    50
# Iris-virginica   Iris-virginica     50
# Name: Species, dtype: int64

# %%
df.boxplot(column=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'])

# %%
df.boxplot(column=['SepalLengthCm'], by='Species')
df.boxplot(column=['SepalWidthCm'], by='Species')
df.boxplot(column=['PetalLengthCm'], by='Species')
df.boxplot(column=['PetalWidthCm'], by='Species')
plt.show()

# %%
import seaborn as sns

# %%
sns.boxplot(x= "Species" , y="PetalLengthCm", data=df)
plt.show()

# %%
sns.violinplot(x="Species",y="PetalLengthCm",data=df)

# %%
sns.pairplot(df, hue="Species")
